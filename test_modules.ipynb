# %%
from module1 import Polygon
from module2 import PolygonSeq

# %% [markdown]
# ### Test Module - 1
# ##### This will produce polygon

# %%
# Polygon with a 20 edges and 8 as circum radius
Polygon(10,8)
# Out:
# Polygon with
#  Edges: 10,
#  Circumradius: 8,
#  Interior Angle: 144.00,
#  Edge Length: 4.94,
#  Apothem: 7.61,
#  Area: 188.09,
#  Perimeter: 49.44

# %%
p1 = Polygon(12,6)
p2 = Polygon(12,6)
p3 = Polygon(15,9)

# %%
p1 == p2
# Out:
# True

# %%
p1 == p3
# Out:
# False

# %%
p3 > p1
# Out:
# True

# %%
p1 > p3
# Out:
# False

# %% [markdown]
# ### Test Module - 2
# ##### This will produce sequence polygon

# %%
PolygonSeq(25,6)
# Out:
# (Polygon with
#  Edges: 3,
#  Circumradius: 6,
#  Interior Angle: 60.00,
#  Edge Length: 10.39,
#  Apothem: 3.00,
#  Area: 46.77,
#  Perimeter: 31.18, Polygon with
#  Edges: 4,
#  Circumradius: 6,
#  Interior Angle: 90.00,
#  Edge Length: 8.49,
#  Apothem: 4.24,
#  Area: 72.00,
#  Perimeter: 33.94, Polygon with
#  Edges: 5,
#  Circumradius: 6,
#  Interior Angle: 108.00,
#  Edge Length: 7.05,
#  Apothem: 4.85,
#  Area: 85.60,
#  Perimeter: 35.27, Polygon with
#  Edges: 6,
#  Circumradius: 6,
#  Interior Angle: 120.00,
#  Edge Length: 6.00,
#  Apothem: 5.20,
#  Area: 93.53,
#  Perimeter: 36.00, Polygon with
#  Edges: 7,
#  Circumradius: 6,
#  Interior Angle: 128.57,
#  Edge Length: 5.21,
#  Apothem: 5.41,
#  Area: 98.51,
#  Perimeter: 36.45, Polygon with
#  Edges: 8,
#  Circumradius: 6,
#  Interior Angle: 135.00,
#  Edge Length: 4.59,
#  Apothem: 5.54,
#  Area: 101.82,
#  Perimeter: 36.74, Polygon with
#  Edges: 9,
#  Circumradius: 6,
#  Interior Angle: 140.00,
#  Edge Length: 4.10,
# ...
